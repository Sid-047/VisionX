# %%
import os
import shutil
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_path = "/content/drive/MyDrive/Yolo_Stuff/train/images"
val_path = "/content/drive/MyDrive/Yolo_Stuff/val/images"
test_path= "/content/drive/MyDrive/Yolo_Stuff/test/set"

# %%
# %cd /content/drive/MyDrive/Yolo_Stuff/yolov7
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Yolo_Stuff/yolov7'
# /content

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !python detect.py --source /content/drive/MyDrive/Yolo_Stuff/test/Set --weights /content/drive/MyDrive/Yolo_Stuff/last.pt --save-txt --save-conf
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=True, save_txt=True, source='/content/drive/MyDrive/Yolo_Stuff/test/Set', update=False, view_img=False, weights=['/content/drive/MyDrive/Yolo_Stuff/last.pt'])
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15109.875MB)
#
# Fusing layers...
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 354 layers, 70807066 parameters, 0 gradients, 188.1 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %%
# !python test.py --source /content/drive/MyDrive/Yolo_Stuff/test/Match_play_.mp4 --weights /content/drive/MyDrive/Yolo_Stuff/yolov7/yolov7-w6-pose.pt --save-txt --save-conf
# Out:
# usage: test.py
#        [-h]
#        [--weights WEIGHTS [WEIGHTS ...]]
#        [--data DATA]
#        [--batch-size BATCH_SIZE]
#        [--img-size IMG_SIZE]
#        [--conf-thres CONF_THRES]
#        [--iou-thres IOU_THRES]
#        [--task TASK]
#        [--device DEVICE]
#        [--single-cls]
#        [--augment]
#        [--verbose]
#        [--save-txt]
#        [--save-hybrid]
#        [--save-conf]
#        [--save-json]
#        [--project PROJECT]
#        [--name NAME]
#        [--exist-ok]
#        [--no-trace]
#        [--v5-metric]
# test.py: error: unrecognized arguments: --source /content/drive/MyDrive/Yolo_Stuff/test/Match_play_.mp4

# %%
from google.colab import files
#files.download('./runs/detect/exp4/10.png')
